# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
df = pd.read_csv("DataSetGenOrgMechanism.csv")
df.head()
# Out:
#    reaction_id substrate_smiles substrate_class leaving_group reagent_smiles  \
# 0            1       CCC(C)(C)I              3°             I            Cl2
# 1            2            CCCCI              1°             I             Br
# 2            3         CCC(C)Cl              2°            Cl             Br
# 3            4            CCCCl              1°            Cl             CO
# 4            5         CCC(C)Cl              2°            Cl            Br2
#
#        reagent_role   solvent_type temperature_class mechanism_class
# 0    radical_source  polar_aprotic         room_temp           other
# 1              acid  polar_aprotic              heat           other
# 2              acid  polar_aprotic               low           other
# 3  weak_nucleophile  polar_aprotic              heat             SN2
# 4    radical_source      non_polar               low           other

# %%
df.tail()
# Out:
#       reaction_id substrate_smiles substrate_class leaving_group  \
# 3995         3996       BrC1CCCCC1              2°            Br
# 3996         3997         CCC(C)Cl              2°            Cl
# 3997         3998       CC(C)(C)Cl              3°            Cl
# 3998         3999             CCBr              1°            Br
# 3999         4000       CC(C)(C)Br              3°            Br
#
#      reagent_smiles        reagent_role   solvent_type temperature_class  \
# 3995            RS-  strong_nucleophile      non_polar               low
# 3996             Cl                acid  polar_aprotic         room_temp
# 3997             Br                acid  polar_aprotic         room_temp
# 3998            RS-  strong_nucleophile  polar_aprotic               low
# 3999            CN-  strong_nucleophile      non_polar               low
#
#      mechanism_class
# 3995           other
# 3996           other
# 3997           other
# 3998             SN2
# 3999           other
